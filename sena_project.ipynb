# %% [markdown]
# ### **<center>Video presentación del caso GA2- 240201528- AA3-EV01</center>**
# #### Aprendiz **<span style="color:blue">Frat Quintero</span>**
# #### Instructora **Yuli Paola Horta**
# #### Ficha **2405116**
#
# ### Información relevante sobre los siguientes estadísticos: *<span style="color:red">cuántos somos; dónde estamos; y cómo vivimos</span>*
# #### Fuente de información: Departamento Administrativo Nacional de Estadística - DANE

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from IPython import display
sns.set_style("dark")

# %% [markdown]
# ### **<span style="color:blue">Cuántos somos</span>**

# %%
display.Image("./Images/cuantos_somos.png")

# %%
# create a series from a dictionary
d = {'2005':41468384, '2008':48258494}
s = pd.Series(d).plot(kind="bar")
plt.title("Cantidad de personas 2005 / 2018")
plt.xlabel("Año")
plt.ylabel("Millones de personas")
# Out:
# Text(0, 0.5, 'Millones de personas')

# %% [markdown]
# La población en Colombia pasó de 41.468.384 habitantes en el año 2005 a 48.258.384 en el censo del 2018, lo cual representa un **incremento del 16.4%**

# %% [markdown]
# ### **<span style="color:blue">Distribución por género</span>**

# %%
display.Image("./Images/men_women.png")

# %% [markdown]
# La distribución por género en el año 2005 era de 49% hombres y 51% mujeres, lo que muestra que para en **comparación con el 2018 la población de mujeres ha aumentado levemente**

# %% [markdown]
# ### **<span style="color:blue">Grupos de edades</span>**

# %%
display.Image("./Images/grupos_de_edad.png")

# %% [markdown]
# Las cifras del censo poblacional de 2018 evidencian que hay **773 personas que superan los 15 años, por cada 1000 habitantes, mientras que en el 2005 tal indicador era 693**, lo cual demuestra que la población joven es menor y hoy en día hay más viejos, lo cual que los retos en materia pensional, aseguramiento en salud y productividad sean mayores.

# %% [markdown]
# ### **<span style="color:blue">Rango de edades</span>**

# %%
display.Image("./Images/estructura_poblacion.png")

# %% [markdown]
# El **bono demográfico** (los jóvenes como el motor del desarrollo) se está perdiendo, situación que se evidencia en el censo del 2018 en el que la edad promedio de los colombianos era de 31 años, mientras que en el censo de 1985 era de 20 años.

# %% [markdown]
# ### **<span style="color:blue">Dónde estamos</span>**

# %%
display.Image("./Images/donde_estamos.png")

# %% [markdown]
# Se observa una migración del campo hacia las ciudades, con un incremento del 1.1% entre los años 2005 y 2018 muy seguramente por temas de seguridad y de falta de oportunidades económicas y de educación

# %% [markdown]
# ### **<span style="color:blue">Cómo vivimos</span>**

# %%
display.Image("./Images/como_vivimos.png")

# %% [markdown]
# El número de viviendas en Colombia se incrementó en un 29.7 porciento en línea con el incremento de la población.

# %% [markdown]
# ### **<span style="color:blue">Personas por vivienda</span>**

# %%
display.Image("./Images/personas_vivienda.png")

# %% [markdown]
# Hoy en día, hay más hogares con 1, 2 y 3 personas que en el 2005. Adicionalmente el porcentaje de hogares con 5 o más personas decreció casi que a la mitad.
